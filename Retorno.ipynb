# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
end_date = datetime.now().strftime('%Y-%m-%d')

PSSA3 = yf.download('PSSA3.SA', start="2019-01-01", end=end_date, progress=False)

PSSA3
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2019-01-02  25.850000  26.250000  25.680000  26.004999  19.892324   960800
# 2019-01-03  25.730000  25.934999  24.950001  25.180000  19.261246  1287200
# 2019-01-04  25.055000  25.180000  24.105000  24.110001  18.442753  2483000
# 2019-01-07  24.125000  24.635000  24.059999  24.594999  18.813751  1271800
# 2019-01-08  24.885000  25.365000  24.535000  25.200001  19.276545  1973600
# ...               ...        ...        ...        ...        ...      ...
# 2023-08-25  27.100000  27.120001  26.549999  27.059999  27.059999  1799400
# 2023-08-28  27.030001  27.059999  26.420000  26.959999  26.959999  1270000
# 2023-08-29  26.950001  27.129999  26.700001  27.010000  27.010000  1515400
# 2023-08-30  26.969999  27.010000  26.540001  26.540001  26.540001  1228400
# 2023-08-31  26.750000  26.760000  26.030001  26.100000  26.100000  1430400
#
# [1161 rows x 6 columns]

# %%
PSSA3.head()
# Out:
#               Open       High        Low      Close  Adj Close   Volume
# Date
# 2019-01-02  25.850  26.250000  25.680000  26.004999  19.892324   960800
# 2019-01-03  25.730  25.934999  24.950001  25.180000  19.261246  1287200
# 2019-01-04  25.055  25.180000  24.105000  24.110001  18.442753  2483000
# 2019-01-07  24.125  24.635000  24.059999  24.594999  18.813751  1271800
# 2019-01-08  24.885  25.365000  24.535000  25.200001  19.276545  1973600

# %%
PSSA3.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2023-08-25  27.100000  27.120001  26.549999  27.059999  27.059999  1799400
# 2023-08-28  27.030001  27.059999  26.420000  26.959999  26.959999  1270000
# 2023-08-29  26.950001  27.129999  26.700001  27.010000  27.010000  1515400
# 2023-08-30  26.969999  27.010000  26.540001  26.540001  26.540001  1228400
# 2023-08-31  26.750000  26.760000  26.030001  26.100000  26.100000  1430400

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
PSSA3['simple_return'] = (PSSA3['Adj Close'] / PSSA3['Adj Close'].shift(1)) - 1
print(PSSA3['simple_return'])
# Out:
# Date
# 2019-01-02         NaN
# 2019-01-03   -0.031725
# 2019-01-04   -0.042494
# 2019-01-07    0.020116
# 2019-01-08    0.024599
#                 ...
# 2023-08-25   -0.001844
# 2023-08-28   -0.003696
# 2023-08-29    0.001855
# 2023-08-30   -0.017401
# 2023-08-31   -0.016579
# Name: simple_return, Length: 1161, dtype: float64

# %%
PSSA3['simple_return'].plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
avg_returns_d = PSSA3['simple_return'].mean()
avg_returns_d
# Out:
# 0.0004133079430144837

# %%
print(str(round(avg_returns_d, 5) * 100) + ' %')
# Out:
# 0.041 %

# %%
avg_returns_a = PSSA3['simple_return'].mean() * 250
avg_returns_a
# Out:
# 0.10332698575362093

# %%
print(str(round(avg_returns_a, 5) * 100) + ' %')
# Out:
# 10.333 %

# %% [markdown]
# # Retorno Logaritimico

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
PSSA3.head()
# Out:
#               Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2019-01-02  25.850  26.250000  25.680000  26.004999  19.892324   960800
# 2019-01-03  25.730  25.934999  24.950001  25.180000  19.261246  1287200
# 2019-01-04  25.055  25.180000  24.105000  24.110001  18.442753  2483000
# 2019-01-07  24.125  24.635000  24.059999  24.594999  18.813751  1271800
# 2019-01-08  24.885  25.365000  24.535000  25.200001  19.276545  1973600
#
#             simple_return
# Date
# 2019-01-02            NaN
# 2019-01-03      -0.031725
# 2019-01-04      -0.042494
# 2019-01-07       0.020116
# 2019-01-08       0.024599

# %%
PSSA3['log_return'] = np.log(PSSA3['Adj Close'] / PSSA3['Adj Close'].shift(1))
print(PSSA3['log_return'])
# Out:
# Date
# 2019-01-02         NaN
# 2019-01-03   -0.032239
# 2019-01-04   -0.043424
# 2019-01-07    0.019917
# 2019-01-08    0.024301
#                 ...
# 2023-08-25   -0.001846
# 2023-08-28   -0.003702
# 2023-08-29    0.001853
# 2023-08-30   -0.017554
# 2023-08-31   -0.016718
# Name: log_return, Length: 1161, dtype: float64

# %%
PSSA3['log_return'].plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
log_return_d = PSSA3['log_return'].mean()
log_return_d
# Out:
# 0.00023413911876448798

# %%
log_return_a = PSSA3['log_return'].mean() * 250
log_return_a
# Out:
# 0.058534779691121995

# %%
print(str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 5.853 %

# %% [markdown]
# # Retorno de uma cateria de Ações

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["ITSA3.SA", "BEES3.SA", "AMER3.SA", "PSSA3.SA"]

data_ativos = yf.download(ativos, start="2019-01-01", end=end_date, progress=False)['Adj Close']

data_ativos
# Out:
#              AMER3.SA  BEES3.SA  ITSA3.SA   PSSA3.SA
# Date
# 2019-01-02  41.664917  2.946821  9.337068  19.892323
# 2019-01-03  42.091255  2.975224  9.527620  19.261242
# 2019-01-04  40.695965  3.095939  9.575259  18.442757
# 2019-01-07  38.893715  3.131441  9.445956  18.813753
# 2019-01-08  40.695965  3.117240  9.486787  19.276548
# ...               ...       ...       ...        ...
# 2023-08-25   0.920000  8.727841  9.460000  27.059999
# 2023-08-28   0.910000  8.717867  9.590000  26.959999
# 2023-08-29   0.930000  8.727841  9.620000  27.010000
# 2023-08-30   0.910000  8.727841  9.480000  26.540001
# 2023-08-31   0.870000  8.727841  9.380000  26.100000
#
# [1161 rows x 4 columns]

# %%
data_ativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1161 entries, 2019-01-02 to 2023-08-31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AMER3.SA  1161 non-null   float64
#  1   BEES3.SA  1161 non-null   float64
#  2   ITSA3.SA  1161 non-null   float64
#  3   PSSA3.SA  1161 non-null   float64
# dtypes: float64(4)
# memory usage: 45.4 KB

# %%
data_ativos.head()
# Out:
#              AMER3.SA  BEES3.SA  ITSA3.SA   PSSA3.SA
# Date
# 2019-01-02  41.664917  2.946821  9.337068  19.892323
# 2019-01-03  42.091255  2.975224  9.527620  19.261242
# 2019-01-04  40.695965  3.095939  9.575259  18.442757
# 2019-01-07  38.893715  3.131441  9.445956  18.813753
# 2019-01-08  40.695965  3.117240  9.486787  19.276548

# %%
data_ativos.tail()
# Out:
#             AMER3.SA  BEES3.SA  ITSA3.SA   PSSA3.SA
# Date
# 2023-08-25      0.92  8.727841      9.46  27.059999
# 2023-08-28      0.91  8.717867      9.59  26.959999
# 2023-08-29      0.93  8.727841      9.62  27.010000
# 2023-08-30      0.91  8.727841      9.48  26.540001
# 2023-08-31      0.87  8.727841      9.38  26.100000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
data_ativos.iloc[0]
# Out:
# AMER3.SA    41.664917
# BEES3.SA     2.946821
# ITSA3.SA     9.337068
# PSSA3.SA    19.892323
# Name: 2019-01-02 00:00:00, dtype: float64

# %%
import matplotlib.pyplot as plt

# Calcula o retorno em relação ao valor inicial e plota o gráfico
retorno_percentual = (data_ativos / data_ativos.iloc[0] * 100)
plt.figure(figsize=(15, 6))
retorno_percentual.plot()
plt.xlabel('Período')
plt.ylabel('Retorno Percentual')
plt.title('Retorno Percentual em Relação ao Valor Inicial')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))
data_ativos.plot()
plt.xlabel('Período')
plt.ylabel('Valor')
plt.title('Valores de Ativos ao Longo do Tempo')
plt.grid(True)
plt.show()

# %%
data_ativos.loc['2023-01-02']
# Out:
# AMER3.SA     9.030000
# BEES3.SA     4.885852
# ITSA3.SA     8.531978
# PSSA3.SA    21.709608
# Name: 2023-01-02 00:00:00, dtype: float64

# %%
data_ativos.iloc[0]
# Out:
# AMER3.SA    41.664917
# BEES3.SA     2.946821
# ITSA3.SA     9.337068
# PSSA3.SA    19.892323
# Name: 2019-01-02 00:00:00, dtype: float64

# %% [markdown]
# # Retorno de uma carteira com segurança

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["ITSA3.SA", "BEES3.SA", "AMER3.SA", "PSSA3.SA"]

data_ativos = yf.download(ativos, start="2023-01-01", end=end_date, progress=False)['Adj Close']

data_ativos
# Out:
#             AMER3.SA  BEES3.SA  ITSA3.SA   PSSA3.SA
# Date
# 2023-01-02      9.03  4.885853  8.531979  21.709608
# 2023-01-03      8.52  4.754057  8.435352  21.297279
# 2023-01-04      8.73  4.895267  8.406365  21.364405
# 2023-01-05      9.69  5.224756  8.589953  21.575363
# 2023-01-06     10.41  5.262412  8.599614  21.863033
# ...              ...       ...       ...        ...
# 2023-08-25      0.92  8.727841  9.460000  27.059999
# 2023-08-28      0.91  8.717867  9.590000  26.959999
# 2023-08-29      0.93  8.727841  9.620000  27.010000
# 2023-08-30      0.91  8.727841  9.480000  26.540001
# 2023-08-31      0.87  8.727841  9.380000  26.100000
#
# [168 rows x 4 columns]

# %%
returns = (data_ativos / data_ativos.shift(1)) - 1
returns.head()
# Out:
#             AMER3.SA  BEES3.SA  ITSA3.SA  PSSA3.SA
# Date
# 2023-01-02       NaN       NaN       NaN       NaN
# 2023-01-03 -0.056478 -0.026975 -0.011325 -0.018993
# 2023-01-04  0.024648  0.029703 -0.003436  0.003152
# 2023-01-05  0.109966  0.067308  0.021839  0.009874
# 2023-01-06  0.074303  0.007207  0.001125  0.013333

# %%
weights = np.array([0.1, 0.4, 0.4, 0.9])

# %%
np.dot(returns, weights)
# Out:
# array([        nan, -0.03806149,  0.01580802,  0.05554219,  0.02276303,
#         0.01930292,  0.03624546,  0.00310761, -0.08622311,  0.01265204,
#        -0.06104719,  0.02114201,  0.02298824, -0.04135743, -0.04481644,
#         0.00708235,  0.01937895,  0.0289203 ,  0.02194681,  0.01993099,
#         0.04900184,  0.05974715, -0.00328185, -0.02661245, -0.00974029,
#         0.01627545, -0.02297638,  0.00510069, -0.02570275,  0.04575205,
#         0.0190335 ,  0.00184179,  0.00038568,  0.03577223,  0.00481972,
#        -0.04260999,  0.02160529, -0.02645404, -0.01422384, -0.00944429,
#        -0.02982735,  0.01247038, -0.00705976,  0.01693474,  0.01592786,
#         0.02343057, -0.00073021, -0.03828657, -0.03394817, -0.01768658,
#         0.00106073,  0.00224013, -0.01735474, -0.02356356, -0.00559096,
#         0.01996342, -0.01339623,  0.00457446, -0.00947   ,  0.01123988,
#        -0.01533743,  0.00457051, -0.00345054, -0.03274571,  0.02300331,
# ...

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# AMER3.SA   -1.612073
# BEES3.SA    0.899403
# ITSA3.SA    0.160988
# PSSA3.SA    0.307730
# dtype: float64

# %%
np.dot(annual_returns, weights)
# Out:
# 0.5399067297111939

# %%
carteira = str(round(np.dot(annual_returns, weights), 5) * 100) + ' %'
print(carteira)
# Out:
# 53.991 %

# %% [markdown]
# # Retorno de ìndeces de Ações

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["^BVSP", "^IBX50", "^IVBX"]

indice_data = yf.download(ativos, start="2019-01-01", end=end_date, progress=False)['Adj Close']

indice_data
# Out:
#                ^BVSP        ^IBX50         ^IVBX
# Date
# 2019-01-02   91012.0  15137.540039  11368.769531
# 2019-01-03   91564.0  15213.559570  11429.839844
# 2019-01-04   91841.0  15260.769531  11409.389648
# 2019-01-07   91699.0  15243.110352  11265.059570
# 2019-01-08   92032.0  15304.349609  11323.790039
# ...              ...           ...           ...
# 2023-08-25  115837.0  19155.089844  12900.209961
# 2023-08-28  117121.0  19384.490234  12954.429688
# 2023-08-29  118404.0  19597.740234  13095.620117
# 2023-08-30  117535.0  19458.599609  12996.790039
# 2023-08-31  115742.0  19182.160156  12780.419922
#
# [1161 rows x 3 columns]

# %%
indice_data.head()
# Out:
#               ^BVSP        ^IBX50         ^IVBX
# Date
# 2019-01-02  91012.0  15137.540039  11368.769531
# 2019-01-03  91564.0  15213.559570  11429.839844
# 2019-01-04  91841.0  15260.769531  11409.389648
# 2019-01-07  91699.0  15243.110352  11265.059570
# 2019-01-08  92032.0  15304.349609  11323.790039

# %%
indice_data.tail()
# Out:
#                ^BVSP        ^IBX50         ^IVBX
# Date
# 2023-08-25  115837.0  19155.089844  12900.209961
# 2023-08-28  117121.0  19384.490234  12954.429688
# 2023-08-29  118404.0  19597.740234  13095.620117
# 2023-08-30  117535.0  19458.599609  12996.790039
# 2023-08-31  115742.0  19182.160156  12780.419922

# %%
(indice_data / indice_data.iloc[0] * 100).plot(figsize = (15, 6))
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
indice_return = (indice_data / indice_data.shift(1)) - 1

indice_return.tail()
# Out:
#                ^BVSP    ^IBX50     ^IVBX
# Date
# 2023-08-25 -0.010160 -0.010102 -0.012677
# 2023-08-28  0.011085  0.011976  0.004203
# 2023-08-29  0.010954  0.011001  0.010899
# 2023-08-30 -0.007339 -0.007100 -0.007547
# 2023-08-31 -0.015255 -0.014207 -0.016648

# %%
annual_indice_return = indice_return.mean() * 250
annual_indice_return
# Out:
# ^BVSP     0.088416
# ^IBX50    0.089455
# ^IVBX     0.064708
# dtype: float64

# %% [markdown]
# # Indice com ação

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["IFIX.SA", "^IBX50", "^BVSP", "^GSPC", "^DJI"]

indice_data2 = yf.download(ativos, start="2019-01-01", progress=False)['Adj Close']

# %%
indice_data2.tail()
# Out:
#                 IFIX.SA     ^BVSP          ^DJI        ^GSPC        ^IBX50
# Date
# 2023-08-25          NaN  115837.0  34346.898438  4405.709961  19155.089844
# 2023-08-28          NaN  117121.0  34559.980469  4433.310059  19384.490234
# 2023-08-29          NaN  118404.0  34852.671875  4497.629883  19597.740234
# 2023-08-30          NaN  117535.0  34890.238281  4514.870117  19458.599609
# 2023-08-31  3212.810059  115742.0  34721.910156  4507.660156  19182.160156

# %%
indice_data2.head()
# Out:
#             IFIX.SA    ^BVSP          ^DJI        ^GSPC        ^IBX50
# Date
# 2019-01-02      NaN  91012.0  23346.240234  2510.030029  15137.540039
# 2019-01-03      NaN  91564.0  22686.220703  2447.889893  15213.559570
# 2019-01-04      NaN  91841.0  23433.160156  2531.939941  15260.769531
# 2019-01-07      NaN  91699.0  23531.349609  2549.689941  15243.110352
# 2019-01-08      NaN  92032.0  23787.449219  2574.409912  15304.349609

# %%
(indice_data2 / indice_data2.iloc[0] * 100).plot(figsize= (15, 6))
plt.show()

# %% [markdown]
# # Risco de um Ativo

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["PSSA3.SA", "BBSE3.SA"]

sec_data = yf.download(ativos, start="2019-01-01", progress=False)['Adj Close']

# %%
sec_data.tail()
# Out:
#              BBSE3.SA   PSSA3.SA
# Date
# 2023-08-25  30.340000  27.059999
# 2023-08-28  30.760000  26.959999
# 2023-08-29  31.049999  27.010000
# 2023-08-30  30.790001  26.540001
# 2023-08-31  30.379999  26.100000

# %%
sec_returns = np.log(sec_data / sec_data.shift(1))
sec_returns
# Out:
#             BBSE3.SA  PSSA3.SA
# Date
# 2019-01-02       NaN       NaN
# 2019-01-03  0.010887 -0.032239
# 2019-01-04 -0.009828 -0.043423
# 2019-01-07 -0.014926  0.019917
# 2019-01-08 -0.014788  0.024301
# ...              ...       ...
# 2023-08-25  0.000000 -0.001846
# 2023-08-28  0.013748 -0.003702
# 2023-08-29  0.009384  0.001853
# 2023-08-30 -0.008409 -0.017554
# 2023-08-31 -0.013406 -0.016718
#
# [1161 rows x 2 columns]

# %% [markdown]
# PSSA3

# %%
sec_returns['PSSA3.SA'].mean()
# Out:
# 0.000234139201422807

# %%
sec_returns['PSSA3.SA'].mean() * 250
# Out:
# 0.05853480035570175

# %%
sec_returns['PSSA3.SA'].std()
# Out:
# 0.01893791946908684

# %%
sec_returns['PSSA3.SA'].std() * 250 ** 0.5
# Out:
# 0.2994347983358056

# %% [markdown]
# BBSE3

# %%
sec_returns['BBSE3.SA'].mean()
# Out:
# 0.00039461287610515844

# %%
sec_returns['BBSE3.SA'].mean() * 250
# Out:
# 0.09865321902628961

# %%
sec_returns['BBSE3.SA'].std()
# Out:
# 0.01783976958655284

# %%
sec_returns['BBSE3.SA'].std() * 250 ** 0.5
# Out:
# 0.28207152413053665

# %%
print(sec_returns['BBSE3.SA'].mean() * 250)
print(sec_returns['PSSA3.SA'].mean() * 250)
# Out:
# 0.09865321902628961
# 0.05853480035570175

# %% [markdown]
# Volatividade

# %%
sec_returns[['BBSE3.SA', 'PSSA3.SA']].mean() * 250
# Out:
# BBSE3.SA    0.098653
# PSSA3.SA    0.058535
# dtype: float64

# %% [markdown]
# Taxa de REtorno/Desvio PAdrão

# %%
sec_returns[['BBSE3.SA', 'PSSA3.SA']].std() * 250 ** 0.5
# Out:
# BBSE3.SA    0.282072
# PSSA3.SA    0.299435
# dtype: float64

# %% [markdown]
# # Covariancia e Correlação

# %%
PSSA3_var = sec_returns['PSSA3.SA'].var()
PSSA3_var
# Out:
# 0.00035864479381761833

# %%
BBSE3_var = sec_returns['BBSE3.SA'].var()
BBSE3_var
# Out:
# 0.0003182573789012957

# %%
PSSA3_var = sec_returns['PSSA3.SA'].var() * 250
PSSA3_var
# Out:
# 0.08966119845440458

# %%
BBSE3_var = sec_returns['BBSE3.SA'].var() * 250
BBSE3_var
# Out:
# 0.07956434472532393

# %%
cov_matrix = sec_returns.cov()
cov_matrix
# Out:
#           BBSE3.SA  PSSA3.SA
# BBSE3.SA  0.000318  0.000151
# PSSA3.SA  0.000151  0.000359

# %%
cov_matrix = sec_returns.cov() * 250
cov_matrix
# Out:
#           BBSE3.SA  PSSA3.SA
# BBSE3.SA  0.079564  0.037710
# PSSA3.SA  0.037710  0.089661

# %%
corr_matrix = sec_returns.corr()
corr_matrix
# Out:
#           BBSE3.SA  PSSA3.SA
# BBSE3.SA  1.000000  0.446471
# PSSA3.SA  0.446471  1.000000

# %% [markdown]
# # Calculando O Risco de uma carteira

# %%
from datetime import datetime
import yfinance as yf

end_date = datetime.now().strftime('%Y-%m-%d')
ativos = ["PSSA3.SA", "AMER3.SA", "KLBN3.SA", "ITSA3.SA", "BEES3.SA", "VGHF11.SA"]

sec_data = yf.download(ativos, start="2019-01-01", progress=False)['Adj Close']

# %%
sec_data.tail()
# Out:
#             AMER3.SA  BEES3.SA  ITSA3.SA  KLBN3.SA   PSSA3.SA  VGHF11.SA
# Date
# 2023-08-28      0.91  8.717867      9.59      4.61  26.959999       9.53
# 2023-08-29      0.93  8.727841      9.62      4.62  27.010000       9.55
# 2023-08-30      0.91  8.727841      9.48      4.58  26.540001       9.61
# 2023-08-31      0.87  8.727841      9.38      4.54  26.100000       9.63
# 2023-09-01      0.90  8.610000      9.47      4.58  26.010000       9.49

# %%
sec_returns = np.log(sec_data / sec_data.shift(1))
sec_returns
# Out:
#             AMER3.SA  BEES3.SA  ITSA3.SA  KLBN3.SA  PSSA3.SA  VGHF11.SA
# Date
# 2019-01-02       NaN       NaN       NaN       NaN       NaN        NaN
# 2019-01-03  0.010181  0.009593  0.020203 -0.021979 -0.032239        NaN
# 2019-01-04 -0.033711  0.039771  0.004988  0.030637 -0.043423        NaN
# 2019-01-07 -0.045296  0.011402 -0.013596  0.048379  0.019916        NaN
# 2019-01-08  0.045296 -0.004546  0.004314 -0.031285  0.024301        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2023-08-28 -0.010929 -0.001143  0.013649  0.008715 -0.003702   0.000000
# 2023-08-29  0.021740  0.001143  0.003123  0.002167  0.001853   0.002096
# 2023-08-30 -0.021740  0.000000 -0.014660 -0.008696 -0.017554   0.006263
# 2023-08-31 -0.044951  0.000000 -0.010604 -0.008772 -0.016718   0.002079
# 2023-09-01  0.033902 -0.013594  0.009549  0.008772 -0.003454  -0.014645
#
# [1162 rows x 6 columns]

# %%
sec_returns[["PSSA3.SA", "AMER3.SA", "KLBN3.SA", "ITSA3.SA", "BEES3.SA", "VGHF11.SA"]].mean() * 250
# Out:
# PSSA3.SA     0.057741
# AMER3.SA    -0.825801
# KLBN3.SA     0.035234
# ITSA3.SA     0.003044
# BEES3.SA     0.230878
# VGHF11.SA   -0.002856
# dtype: float64

# %%
weights = np.array([0.11, 0.03, 0.03, 0.11, 0.70, 0.12])

# %% [markdown]
# Carteira Variância: A variância de ativos é um conceito importante no campo de finanças e investimentos. Ela é uma medida estatística que quantifica a dispersão ou volatilidade dos retornos de um ativo financeiro ao longo do tempo. Quanto maior a variância, maior a flutuação dos retornos, o que geralmente indica um nível de risco mais alto associado ao ativo.

# %%
cart_var = np.dot(weights.T, np.dot(sec_returns.cov() * 250, weights))
cart_var
# Out:
# 0.07666974573879808

# %% [markdown]
# Carteira Volatividade :
# A volatilidade de ativos é uma medida da variação dos preços de um ativo ao longo do tempo. Ela é frequentemente utilizada para avaliar o risco associado a um investimento. Quanto maior a volatilidade de um ativo, maior é a probabilidade de seus preços flutuarem significativamente em curtos períodos de tempo.

# %%
cart_vol = (np.dot(weights.T, np.dot(sec_returns.cov() * 250, weights))) ** 0.5
cart_vol
# Out:
# 0.27689302219232265

# %%
print(str(round(cart_vol, 5) * 100) + ' %')
# Out:
# 27.689000000000004 %

# %% [markdown]
# # Calcular Risco Diverrsificavel e não diversificavel

# %%
weights = np.array([0.11, 0.03, 0.03, 0.11, 0.70, 0.12])

# %%
weights[0]
# Out:
# 0.9

# %%
weights[1]
# Out:
# 0.2

# %% [markdown]
# Risco Diversificavel

# %% [markdown]
# AMER3.SA	BEES3.SA	ITSA3.SA	KLBN3.SA	PSSA3.SA	VGHF11.SA

# %%
AMER3_var_a = sec_returns["AMER3.SA"].var() * 250
AMER3_var_a
# Out:
# 1.1138553264240243

# %%
PSSA3_var_a = sec_returns["PSSA3.SA"].var() * 250
PSSA3_var_a
# Out:
# 0.0895868589412989

# %%
KLBN3_var_a = sec_returns["KLBN3.SA"].var() * 250
KLBN3_var_a
# Out:
# 0.1337285649858267

# %%
ITSA3_var_a = sec_returns["ITSA3.SA"].var() * 250
ITSA3_var_a
# Out:
# 0.06299305798644853

# %%
BEES3_var_a = sec_returns["BEES3.SA"].var() * 250
BEES3_var_a
# Out:
# 0.05624109138878372

# %%
VGHF11_var_a = sec_returns["VGHF11.SA"].var() * 250
VGHF11_var_a
# Out:
# 0.01279534697298383

# %% [markdown]
# AMER3.SA	BEES3.SA	ITSA3.SA	KLBN3.SA	PSSA3.SA	VGHF11.SA

# %%
dr = cart_var  - (weights[0] ** 2 * AMER3_var_a)  - (weights[1] ** 2 * BEES3_var_a)  - (weights[2] ** 2 * ITSA3_var_a)  - (weights[3] ** 2 * KLBN3_var_a)  - (weights[4] ** 2 * PSSA3_var_a) -  (weights[5] ** 2 * VGHF11_var_a)
dr
# Out:
# 0.017384856040653738

# %%
print(str(round(dr*100, 3)) + ' %')
# Out:
# 1.738 %

# %% [markdown]
# Não Diversificavel

# %%
n_dr_2 = cart_var - dr
n_dr_2
# Out:
# 0.05928488969814434

# %%
n_dr_2 = (weights[0] ** 2 * AMER3_var_a) -  - (weights[1] ** 2 * BEES3_var_a)  - (weights[2] ** 2 * ITSA3_var_a)  - (weights[3] ** 2 * KLBN3_var_a)  - (weights[4] ** 2 * PSSA3_var_a) -  (weights[5] ** 2 * VGHF11_var_a)
n_dr_2
# Out:
# -0.03222835683418314
